# %% [markdown]
# # MDP Lesson 4:  Total Reward MDP with two-dimensional state space

# %% [markdown]
# ### Using the library

# %%
import marmote.core as mc 
import marmote.mdp as md

# %%
import numpy as np

# %% [markdown]
# ## Build a MDP associated with a Stochastic Shortest Path

# %% [markdown]
# ### Description of the model

# %% [markdown]
# We consider the (classic) four rooms model which is represented on the figure below. This model is related to a *Stochastic Shortest Path*. The state space is divided into 4 rooms, each with (5 x 5) positions. You can only move from one room to another at particular locations. There is also an exit state from the system, which yields a gain. Moving from one position to another incurs a cost.

# %% [markdown]
# <img src="./FourRooms.png">

# %% [markdown]
# More Precisely:
#
# We assume that the state space has two dimensions 11 lines x 10 columns ([0,10]*[0,9])
#
# If we reach the state (9,2) we receive a reward of -1 and we go in state (10,2). In any state in line 10 we stay in this state without receiving anything (absorbing states).
#
# There is wall between line 4 and 5 that can be crossed
#  -> at states (4,2)->(5,2) and (4,7)->(5,7)
#  -> at states (5,2)->(4,2) and (5,7)->(4,7)
#
# There is a wall between column 4 and 5 that can be crossed
#  -> at states (2,4)->(2,5) and (7,4)->(7,5)
#  -> at states (2,5)->(2,4) and (7,5)->(7,4)
#
# There are 4 actions: 0 is up 1 is down 2 is left and 3 is right. With a probability *p=0.9* the action has the desired effect and with probability *1-p* the action has no effect.
# Performing an action in any state except (9,2) has a cost of 1.

# %% [markdown]
# ## Multidimensional State Space

# %% [markdown]
# In all what follows we consider a two dimensionals state space with first dimension equals to 11 and second dimension equal to 10.

# %% [markdown]
# ### Creating Spaces

# %% [markdown]
# **Definitions of the state**

# %% [markdown]
# The object used to create the state space is a `MarmoteBox` with dimension 11 x 10.
# First define the dimensions of the box in a numpy array

# %%
dims = np.array([11, 10])

# %% [markdown]
# Then create the box (and illustrate this by printing the cardinal, the dimension and the object)

# %%
stateSpace = mc.MarmoteBox(dims)

dim_SS = stateSpace.Cardinal()
print("State Space cardinal",dim_SS)
print("State Space dimension",stateSpace.tot_nb_dims())
print("State Space type",stateSpace)
# Out:
# State Space cardinal 110
# State Space dimension 2
# State Space type Box( [ 0..10 ] x [ 0..9 ] )

# %% [markdown]
# Create the action space as an interval between 0 and 3

# %%
actionSpace = mc.MarmoteInterval(0,3)
dim_AS = actionSpace.Cardinal()

# %% [markdown]
# **Associate a state to a variable**

# %% [markdown]
# It is possible to associate a state either to a buffer of to a numpy array (both ways are used in this notebook). The buffer or the array stores the different values of a given state.
# Furthermore to each state is associated an index. it is then possible to pass from a state to an index and conversely.
#
# Here one creates two arrays: one to represent the initial state (before transition) and the second one to represent the state after transition. The state is *(0,0)* in the following instruction.

# %%
# First tab allows to manage initial state 
etat=np.array([0,0])
# Second tab allows to manage final state (after transition)
sortie=np.array([0,0])

# %% [markdown]
# **Filling Cost matrix**

# %% [markdown]
# We fill in the matrix : all the costs are equal to 1 except in 9,2 in which it is equal to -1 and in line 10 in which it is equal to 0

# %%
print("Fill in Cost Matrix")
CostMat  =  mc.FullMatrix(dim_SS, dim_AS)

#definition of some indexes
k=0  # to iterate on states
l=0 # to iterate on lines
c=0 # to iterate on columns
indexO=0 # indexes of the initial state
indexD=0 # indexes of the final state


stateSpace.FirstState(etat)
for k in range(dim_SS):
        # computing the index of the state
        indexO=stateSpace.Index(etat)
        # for each state we give a value of any action
        for a in range(dim_AS) :
                CostMat.setEntry(indexO,a,1)
        stateSpace.NextState(etat)

# replacing the term in (9,2) with action UP to -1
etat[0]=9
etat[1]=2
indexO=stateSpace.Index(etat)
print("index of state (9,2) ",indexO,"\n")
CostMat.setEntry(indexO,0,-1.0)

# Fill in the line 10 all costs are equal to zero
# Define the line
etat[0]=10
for k in range(10):
    etat[1]=k
    indexO=stateSpace.Index(etat)
    CostMat.setEntry(indexO,0,0.0)
    CostMat.setEntry(indexO,1,0.0)
    CostMat.setEntry(indexO,2,0.0)
    CostMat.setEntry(indexO,3,0.0)
# Out:
# Fill in Cost Matrix
# index of state (9,2)  92

# %% [markdown]
# ### Use a third way to build the MDP

# %% [markdown]
# In what follows, we use a constructor that does not require to build the list of matrices. They are added one by one.
# Please notice that the name of the matrices should differ.

# %%
# create and initialize elements of MDP
criterion="min"

print("Begining of building MDP")
# create the MDP
mdpSSP =  md.TotalRewardMDP(criterion, stateSpace, actionSpace, CostMat)
print("End of building MDP")
# Out:
# Begining of building MDP
# End of building MDP

# %% [markdown]
# Then we fill in the transition matrices. Then we have four matrices to fill in.
#
# First we complete matrix for action 0 (UP). All the states are browsed by iterating over the rows and columns. For each new state value, the index is calculated, then the possible output states and their indexes are computed to fill in the entry.

# %%
print("Add matrices")


p=0.9

P0 =  mc.SparseMatrix(dim_SS)
for l in range(10) :
        for c in range(10):
                # define a state and get its index
                etat[0]=l # initialize the value of the first dim
                etat[1]=c # initialize the value of the second dim
                indexO=stateSpace.Index(etat)
                if (( l==4) or (l==9)) :
                        if  ( (l==4) and  ( (c==2) or (c==7)) ) :
                                # I am on a door two possibilities
                                # either I move up with probability p
                                sortie[0]=l+1
                                sortie[1]=c
                                indexD=stateSpace.Index(sortie) #computing the index of destination
                                P0.setEntry(indexO,indexD,p)
                                # either I stay
                                P0.setEntry(indexO,indexO,1-p)
                        else:
                                if  ( (l==9) and (c==2)):
                                # I am on a door two possibilities
                                    # either I move up with probability p
                                        sortie[0]=l+1
                                        sortie[1]=c
                                        indexD=stateSpace.Index(sortie) #computing the index of destination
                                        P0.setEntry(indexO,indexD,p)
                                #either I stay
                                        P0.setEntry(indexO,indexO,1-p)
                                else:
                                # I am on the wall l=4 or l=9 I stay in the same state
                                        P0.setEntry(indexO,indexO,1.0)
                else:
                #I am whatever in a rooms I have two possibilities
                # either I move up with probability p
                        sortie[0]=l+1
                        sortie[1]=c
                        indexD=stateSpace.Index(sortie) #computing the index of destination
                        P0.setEntry(indexO,indexD,p)
                #either I stay
                        P0.setEntry(indexO,indexO,1-p)

# fill in last line
for c in range(10):
        # define a state and get its index
                etat[0]=10 # initialize the value of the first dim
                etat[1]=c # initialize the value of the second dim
                indexO=stateSpace.Index(etat)
                P0.setEntry(indexO,indexO,1.0)


mdpSSP.AddMatrix(0,P0)
print("Added matrix (action 0)")
# Out:
# Add matrices
# Added matrix (action 0)

# %% [markdown]
# We complete the remaining matrices

# %%
# Complete matrix for action 1 (DOWN)
P1 =  mc.SparseMatrix(dim_SS)

for l in range(10) :
        for c in range(10) :
                # define a state and get its index
                etat[0]=l # initialize the value of the first dim
                etat[1]=c # initialize the value of the second dim
                indexO=stateSpace.Index(etat)
                if ((l==5) or (l==0)) :
                        if ((l==5) and ( (c==2) or (c==7)) ) :
                                #two possibilities I am on a door
                                #either I move down with probability p
                                sortie[0]=l-1
                                sortie[1]=c
                                indexD=stateSpace.Index(sortie) #computing the index of destination
                                P1.setEntry(indexO,indexD,p)
                                #either I stay
                                P1.setEntry(indexO,indexO,1-p)
                        else:
                                        #I am on the wall l=5 or l=0 I stay in the same state
                                        P1.setEntry(indexO,indexO,1.0)
                else:
                                # I am whatever in a rooms I have two possibilities
                                # either I move down with probability p
                                # or I stay with a probability 1-p
                                sortie[0]=l-1
                                sortie[1]=c
                                indexD=stateSpace.Index(sortie) #computing the index of destination
                                P1.setEntry(indexO,indexD,p)
                                # either I stay
                                P1.setEntry(indexO,indexO,1-p)

# fill in last line
for c in range(10) :
        # define a state and get its index
        etat[0]=10 # initialize the value of the first dim
        etat[1]=c # initialize the value of the second dim
        indexO=stateSpace.Index(etat)
        P1.setEntry(indexO,indexO,1.0)


mdpSSP.AddMatrix(1,P1)
print("Added matrix (action 1)")

# Define matrix for action 2 (LEFT)
P2 =  mc.SparseMatrix(dim_SS)
for l in range(10) :
        for c in range(10) :
                # define a state and get its index
                etat[0]=l # initialize the value of the first dim
                etat[1]=c # initialize the value of the second dim
                indexO=stateSpace.Index(etat)
                if ((c==5) or (c==0)) :
                        if ((c==5) and ( (l==2) or (l==7)) ) :
                                # I am on a door
                                # either I move left with probability p
                                # or I stay with propability 1-p
                                sortie[0]=l
                                sortie[1]=c-1
                                indexD=stateSpace.Index(sortie) #computing the index of destination
                                P2.setEntry(indexO,indexD,p)
                                #either I stay
                                P2.setEntry(indexO,indexO,1-p)
                        else :
                                # I am on the wall c=5 or c=0 I stay in the same state
                                P2.setEntry(indexO,indexO,1.0)
                else :
                        #I am whatever in a rooms I have two possibilities
                        #either i move left with probability p
                        sortie[0]=l
                        sortie[1]=c-1
                        indexD=stateSpace.Index(sortie) #computing the index of destination
                        P2.setEntry(indexO,indexD,p)
                        # or I stay
                        P2.setEntry(indexO,indexO,1-p)

# fill in last line
for c in range(10) :
        # define a state and get its index
        etat[0]=10 # initialize the value of the first dim
        etat[1]=c # initialize the value of the second dim
        indexO=stateSpace.Index(etat)
        P2.setEntry(indexO,indexO,1.0)

mdpSSP.AddMatrix(2,P2)
print("Added matrix (action 2)")

# Define matrix for action 3 (RIGHT)
P3 =  mc.SparseMatrix(dim_SS)
for l in range(10) :
        for c in range(10) :
                # define a state and get its index
                etat[0]=l # initialize the value of the first dim
                etat[1]=c # initialize the value of the second dim
                indexO=stateSpace.Index(etat)
                if ((c==4) or (c==9)) :
                        if ((c==4) and ( (l==2) or (l==7)) ) :
                                # I am on a door
                                # either I move right with probability p
                                # or I stay with propability 1-p
                                sortie[0]=l
                                sortie[1]=c+1
                                indexD=stateSpace.Index(sortie) #computing the index of destination
                                P3.setEntry(indexO,indexD,p)
                                # either I stay
                                P3.setEntry(indexO,indexO,1-p)
                        else :
                # I am on the wall c=4 or c=9 I stay in the same state
                                P3.setEntry(indexO,indexO,1.0)
                else :
                        # I am whatever in a rooms I have two possibilities
                        # either i move left with probability p
                        sortie[0]=l
                        sortie[1]=c+1
                        indexD=stateSpace.Index(sortie) #computing the index of destination
                        P3.setEntry(indexO,indexD,p)
                        # either I stay
                        P3.setEntry(indexO,indexO,1-p)

# fill in last line
for c in range(10) :
        # define a state and get its index
        etat[0]=10 # initialize the value of the first dim
        etat[1]=c # initialize the value of the second dim
        indexO=stateSpace.Index(etat)
        P3.setEntry(indexO,indexO,1.0)


mdpSSP.AddMatrix(3,P3)
print("Added matrix (action 3)")


print("Finishing Adding matrices MDP")
print("Writing MDP")
print(mdpSSP)
# Out:
# Added matrix (action 1)
# Added matrix (action 2)
# Added matrix (action 3)
# Finishing Adding matrices MDP
# Writing MDP
# #############################################
# # Model total Reward MDP
# # MDP Criteria : Total reward
# #############################################
# #############################################
# MDP type (discrete,continuous): discrete
# MDP rule (min,max): min
# State space size: 110
# Action space size: 4
# State  dimension: 2
# Action dimension: 1
# #############################################
# Transition matrix per action:
# action: 0
#          0         10 9.000000e-01
#          0          0 1.000000e-01
#          1         11 9.000000e-01
#          1          1 1.000000e-01
#          2         12 9.000000e-01
#          2          2 1.000000e-01
#          3         13 9.000000e-01
#          3          3 1.000000e-01
#          4         14 9.000000e-01
#          4          4 1.000000e-01
#          5         15 9.000000e-01
#          5          5 1.000000e-01
#          6         16 9.000000e-01
#          6          6 1.000000e-01
#          7         17 9.000000e-01
#          7          7 1.000000e-01
#          8         18 9.000000e-01
#          8          8 1.000000e-01
#          9         19 9.000000e-01
#          9          9 1.000000e-01
#         10         20 9.000000e-01
#         10         10 1.000000e-01
#         11         21 9.000000e-01
#         11         11 1.000000e-01
#         12         22 9.000000e-01
#         12         12 1.000000e-01
#         13         23 9.000000e-01
#         13         13 1.000000e-01
#         14         24 9.000000e-01
#         14         14 1.000000e-01
#         15         25 9.000000e-01
#         15         15 1.000000e-01
#         16         26 9.000000e-01
#         16         16 1.000000e-01
#         17         27 9.000000e-01
#         17         17 1.000000e-01
#         18         28 9.000000e-01
#         18         18 1.000000e-01
#         19         29 9.000000e-01
#         19         19 1.000000e-01
#         20         30 9.000000e-01
#         20         20 1.000000e-01
#         21         31 9.000000e-01
#         21         21 1.000000e-01
#         22         32 9.000000e-01
#         22         22 1.000000e-01
#         23         33 9.000000e-01
#         23         23 1.000000e-01
#         24         34 9.000000e-01
#         24         24 1.000000e-01
#         25         35 9.000000e-01
#         89          3 1.000000e+00
#         90          0 1.000000e+00
#         90          1 1.000000e+00
#         90          2 1.000000e+00
#         90          3 1.000000e+00
#         91          0 1.000000e+00
#         91          1 1.000000e+00
#         91          2 1.000000e+00
#         91          3 1.000000e+00
#         92          0 -1.000000e+00
#         92          1 1.000000e+00
#         92          2 1.000000e+00
#         92          3 1.000000e+00
#         93          0 1.000000e+00
#         93          1 1.000000e+00
#         93          2 1.000000e+00
#         93          3 1.000000e+00
#         94          0 1.000000e+00
#         94          1 1.000000e+00
#         94          2 1.000000e+00
#         94          3 1.000000e+00
#         95          0 1.000000e+00
#         95          1 1.000000e+00
#         95          2 1.000000e+00
#         95          3 1.000000e+00
#         96          0 1.000000e+00
#         96          1 1.000000e+00
#         96          2 1.000000e+00
#         96          3 1.000000e+00
#         97          0 1.000000e+00
#         97          1 1.000000e+00
#         97          2 1.000000e+00
#         97          3 1.000000e+00
#         98          0 1.000000e+00
#         98          1 1.000000e+00
#         98          2 1.000000e+00
#         98          3 1.000000e+00
#         99          0 1.000000e+00
#         99          1 1.000000e+00
#         99          2 1.000000e+00
#         99          3 1.000000e+00
#        100          0 0.000000e+00
#        100          1 0.000000e+00
#        100          2 0.000000e+00
#        100          3 0.000000e+00
#        101          0 0.000000e+00
#        101          1 0.000000e+00
#        101          2 0.000000e+00
#        101          3 0.000000e+00
#        102          0 0.000000e+00
#        102          1 0.000000e+00
#        102          2 0.000000e+00
#        102          3 0.000000e+00
#        103          0 0.000000e+00
#        103          1 0.000000e+00
#        103          2 0.000000e+00
#        103          3 0.000000e+00
#        104          0 0.000000e+00
#        104          1 0.000000e+00
#        104          2 0.000000e+00
#        104          3 0.000000e+00
#        105          0 0.000000e+00
#        105          1 0.000000e+00
#        105          2 0.000000e+00
#        105          3 0.000000e+00
#        106          0 0.000000e+00
#        106          1 0.000000e+00
#        106          2 0.000000e+00
#        106          3 0.000000e+00
#        107          0 0.000000e+00
#        107          1 0.000000e+00
#        107          2 0.000000e+00
#        107          3 0.000000e+00
#        108          0 0.000000e+00
#        108          1 0.000000e+00
#        108          2 0.000000e+00
#        108          3 0.000000e+00
#        109          0 0.000000e+00
#        109          1 0.000000e+00
#        109          2 0.000000e+00
#        109          3 0.000000e+00
#
# #############################################

# %%
# create and initialize elements of solving
epsilon = 0.0001
maxIter=250

print("\nPrinting solution from value iteration")
optimum2 = mdpSSP.ValueIteration(epsilon, maxIter)
print(optimum2)
# Out:
# Printing solution from value iteration
# #############################################
# Solution of MDP problem
# Size of the state space: 110
# #############################################
# Solution model: Feedback Stationary Policy
# - column 1: index of the state
# - column 2: Value function
# - column 3: Optimal action
#
#   0           11.1111   0
#   1                10   0
#   2           8.88889   0
#   3                10   0
#   4           11.1111   0
#   5           12.2222   0
#   6           13.3333   0
#   7           14.4444   0
#   8           15.5556   0
#   9           16.6667   0
#  10                10   0
#  11           8.88889   0
#  12           7.77778   0
#  13           8.88889   0
#  14                10   0
#  15           11.1111   0
#  16           12.2222   0
#  17           13.3333   0
#  18           14.4444   0
#  19           15.5556   0
#  20           8.88889   0
#  21           7.77778   0
#  22           6.66667   0
#  23           7.77778   0
#  24           8.88889   0
#  25                10   2
#  26           11.1111   2
#  27           12.2222   0
#  28           13.3333   0
#  29           14.4444   0
#  30           7.77778   0
#  31           6.66667   0
#  32           5.55556   0
#  33           6.66667   0
#  34           7.77778   0
#  35           11.1111   1
#  36           12.2222   0
#  37           11.1111   0
#  38           12.2222   0
#  39           13.3333   0
#  40           6.66667   3
#  41           5.55556   3
#  42           4.44444   0
#  43           5.55556   2
#  44           6.66667   2
#  45           12.2222   1
#  46           11.1111   3
#  47                10   0
#  48           11.1111   2
#  49           12.2222   2
#  50           5.55556   0
#  51           4.44444   0
#  52           3.33333   0
#  53           4.44444   0
#  54           5.55556   0
#  55           6.66667   0
#  56           7.77778   0
#  57           8.88889   0
#  58                10   0
#  59           11.1111   0
#  60           4.44444   0
#  61           3.33333   0
#  62           2.22222   0
#  63           3.33333   0
#  64           4.44444   0
#  65           5.55556   0
#  66           6.66667   0
#  67           7.77778   0
#  68           8.88889   0
#  69                10   0
#  70           3.33333   0
#  71           2.22222   0
#  72           1.11111   0
#  73           2.22222   0
#  74           3.33333   0
#  75           4.44444   2
#  76           5.55556   2
#  77           6.66667   2
#  78           7.77778   2
#  79           8.88889   2
#  80           2.22222   0
#  81           1.11111   0
#  82                 0   0
#  83           1.11111   0
#  84           2.22222   0
#  85           5.55556   1
#  86           6.66667   1
#  87           7.77778   1
#  88           8.88889   1
#  89                10   1
#  90           1.11111   3
#  91                 0   3
#  92          -1.11111   0
#  93                 0   2
#  94           1.11111   2
#  95           6.66667   1
#  96           7.77778   1
#  97           8.88889   1
#  98                10   1
#  99           11.1111   1
# 100                 0   0
# 101                 0   0
# 102                 0   0
# 103                 0   0
# 104                 0   0
# 105                 0   0
# 106                 0   0
# 107                 0   0
# 108                 0   0
# 109                 0   0
# #############################################

# %% [markdown]
# ### Print policy dimension by dimension

# %% [markdown]
# A `FeedbackSolutionMDP` can be printed dimension by dimension with method `SolutionByDim` whose first parameter is the dimension to be scanned. Below we scan the columns. THe line is fixed and we let vary the columns.

# %%
print("Print solution by dimension (line by line)")
line=optimum2.SolutionByDim(1,stateSpace)
print(line)
# Out:
# Print solution by dimension (line by line)
# Solution of MDP problem
# Size of the state space : 110
# Dimension to follow : 1
# #############################################
# # Solution of the entered problem model:
# # - column 1: index of the state
# # - column 2: Value function
# # - column 3: Optimal action
# #
#  etat : 0	(   0,   0)	         11.1111   0
#  etat : 1	(   0,   1)	              10   0
#  etat : 2	(   0,   2)	         8.88889   0
#  etat : 3	(   0,   3)	              10   0
#  etat : 4	(   0,   4)	         11.1111   0
#  etat : 5	(   0,   5)	         12.2222   0
#  etat : 6	(   0,   6)	         13.3333   0
#  etat : 7	(   0,   7)	         14.4444   0
#  etat : 8	(   0,   8)	         15.5556   0
#  etat : 9	(   0,   9)	         16.6667   0
#
#  etat : 74	(   7,   4)	         3.33333   0
#  etat : 75	(   7,   5)	         4.44444   2
#  etat : 76	(   7,   6)	         5.55556   2
#  etat : 77	(   7,   7)	         6.66667   2
#  etat : 78	(   7,   8)	         7.77778   2
#  etat : 79	(   7,   9)	         8.88889   2
#
#  etat : 80	(   8,   0)	         2.22222   0
#  etat : 81	(   8,   1)	         1.11111   0
#  etat : 82	(   8,   2)	               0   0
#  etat : 83	(   8,   3)	         1.11111   0
#  etat : 84	(   8,   4)	         2.22222   0
#  etat : 85	(   8,   5)	         5.55556   1
#  etat : 86	(   8,   6)	         6.66667   1
#  etat : 87	(   8,   7)	         7.77778   1
#  etat : 88	(   8,   8)	         8.88889   1
#  etat : 89	(   8,   9)	              10   1
#
#  etat : 90	(   9,   0)	         1.11111   3
#  etat : 91	(   9,   1)	               0   3
#  etat : 92	(   9,   2)	        -1.11111   0
#  etat : 93	(   9,   3)	               0   2
#  etat : 94	(   9,   4)	         1.11111   2
#  etat : 95	(   9,   5)	         6.66667   1
#  etat : 96	(   9,   6)	         7.77778   1
#  etat : 97	(   9,   7)	         8.88889   1
#  etat : 98	(   9,   8)	              10   1
#  etat : 99	(   9,   9)	         11.1111   1
#
#  etat : 100	(  10,   0)	               0   0
#  etat : 101	(  10,   1)	               0   0
#  etat : 102	(  10,   2)	               0   0
#  etat : 103	(  10,   3)	               0   0
#  etat : 104	(  10,   4)	               0   0
#  etat : 105	(  10,   5)	               0   0
#  etat : 106	(  10,   6)	               0   0
#  etat : 107	(  10,   7)	               0   0
#  etat : 108	(  10,   8)	               0   0
#  etat : 109	(  10,   9)	               0   0
#
# #############################################

# %% [markdown]
# ### Enumerating the policy

# %% [markdown]
# We can scan the policy by the way of the *iterator* of space. We also create a *buffer* to store the state.

# %%
#create the buffer
bbuf = stateSpace.StateBuffer()
print("Printing State Space Path and value function with a browsing by iterating space")
# initial state (bbuf receive the value of the first state of the state space
stateSpace.FirstState(bbuf)
# scan
for k in range(stateSpace.Cardinal()):
        # getting the index of the state
        indexO = stateSpace.Index(bbuf)
        # the different values of the states are in the array
        l=bbuf[0] # getting value of the first dimension of the box
        c=bbuf[1] # getting value of the second dimension of the box    
        print("--State in line=", l , " column=", c, end = ' ')
        if ((c<=4) and (l<=4)) :
                print(" --in Room at Bottom Left  ", end = ' ')
        if ((c<=4) and (l>=5)) :
                print(" --in Room at Top Left     ", end = ' ')
        if ((c>=5) and (l<=4)) :
                print(" --in Room at Bottom Right ", end = ' ')
        if ((c>=5) and (l>=5)) :
                print(" --in Room at Top Right    ", end = ' ')
        # getting the values and the action at the index of the state
        print( " --Optimal Action=" , optimum2.getActionIndex(indexO) , " --Value=" , optimum2.getValueIndex(indexO) )
        # Move to next state
        stateSpace.NextState(bbuf)
# Out:
# Printing State Space Path and value function with a browsing by iterating space
# --State in line= 0  column= 0  --in Room at Bottom Left    --Optimal Action= 0  --Value= 11.111111111563469
# --State in line= 0  column= 1  --in Room at Bottom Left    --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 0  column= 2  --in Room at Bottom Left    --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 0  column= 3  --in Room at Bottom Left    --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 0  column= 4  --in Room at Bottom Left    --Optimal Action= 0  --Value= 11.111111111563469
# --State in line= 0  column= 5  --in Room at Bottom Right   --Optimal Action= 0  --Value= 12.222222227640405
# --State in line= 0  column= 6  --in Room at Bottom Right   --Optimal Action= 0  --Value= 13.333333389457422
# --State in line= 0  column= 7  --in Room at Bottom Right   --Optimal Action= 0  --Value= 14.444444947828393
# --State in line= 0  column= 8  --in Room at Bottom Right   --Optimal Action= 0  --Value= 15.555559463358785
# --State in line= 0  column= 9  --in Room at Bottom Right   --Optimal Action= 0  --Value= 16.66669286901964
# --State in line= 1  column= 0  --in Room at Bottom Left    --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 1  column= 1  --in Room at Bottom Left    --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 1  column= 2  --in Room at Bottom Left    --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 1  column= 3  --in Room at Bottom Left    --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 1  column= 4  --in Room at Bottom Left    --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 1  column= 5  --in Room at Bottom Right   --Optimal Action= 0  --Value= 11.111111111563469
# --State in line= 1  column= 6  --in Room at Bottom Right   --Optimal Action= 0  --Value= 12.222222227640405
# --State in line= 1  column= 7  --in Room at Bottom Right   --Optimal Action= 0  --Value= 13.333333389457422
# --State in line= 1  column= 8  --in Room at Bottom Right   --Optimal Action= 0  --Value= 14.444444947828393
# --State in line= 1  column= 9  --in Room at Bottom Right   --Optimal Action= 0  --Value= 15.555559463358785
# --State in line= 2  column= 0  --in Room at Bottom Left    --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 2  column= 1  --in Room at Bottom Left    --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 2  column= 2  --in Room at Bottom Left    --Optimal Action= 0  --Value= 6.6666666666666705
# --State in line= 2  column= 3  --in Room at Bottom Left    --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 2  column= 4  --in Room at Bottom Left    --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 2  column= 5  --in Room at Bottom Right   --Optimal Action= 2  --Value= 10.000000000032566
# --State in line= 2  column= 6  --in Room at Bottom Right   --Optimal Action= 2  --Value= 11.111111111563469
# --State in line= 2  column= 7  --in Room at Bottom Right   --Optimal Action= 0  --Value= 12.222222227640405
# --State in line= 2  column= 8  --in Room at Bottom Right   --Optimal Action= 0  --Value= 13.333333389457422
# --State in line= 2  column= 9  --in Room at Bottom Right   --Optimal Action= 0  --Value= 14.444444947828393
# --State in line= 3  column= 0  --in Room at Bottom Left    --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 3  column= 1  --in Room at Bottom Left    --Optimal Action= 0  --Value= 6.6666666666666705
# --State in line= 3  column= 2  --in Room at Bottom Left    --Optimal Action= 0  --Value= 5.555555555555555
# --State in line= 3  column= 3  --in Room at Bottom Left    --Optimal Action= 0  --Value= 6.6666666666666705
# --State in line= 3  column= 4  --in Room at Bottom Left    --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 3  column= 5  --in Room at Bottom Right   --Optimal Action= 1  --Value= 11.111111111563469
# --State in line= 3  column= 6  --in Room at Bottom Right   --Optimal Action= 0  --Value= 12.222222227640405
# --State in line= 3  column= 7  --in Room at Bottom Right   --Optimal Action= 0  --Value= 11.111111111563469
# --State in line= 3  column= 8  --in Room at Bottom Right   --Optimal Action= 0  --Value= 12.222222227640405
# --State in line= 3  column= 9  --in Room at Bottom Right   --Optimal Action= 0  --Value= 13.333333389457422
# --State in line= 4  column= 0  --in Room at Bottom Left    --Optimal Action= 3  --Value= 6.6666666666666705
# --State in line= 4  column= 1  --in Room at Bottom Left    --Optimal Action= 3  --Value= 5.555555555555555
# --State in line= 4  column= 2  --in Room at Bottom Left    --Optimal Action= 0  --Value= 4.444444444444445
# --State in line= 4  column= 3  --in Room at Bottom Left    --Optimal Action= 2  --Value= 5.555555555555555
# --State in line= 4  column= 4  --in Room at Bottom Left    --Optimal Action= 2  --Value= 6.6666666666666705
# --State in line= 4  column= 5  --in Room at Bottom Right   --Optimal Action= 1  --Value= 12.222222227640405
# --State in line= 4  column= 6  --in Room at Bottom Right   --Optimal Action= 3  --Value= 11.111111111563469
# --State in line= 4  column= 7  --in Room at Bottom Right   --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 4  column= 8  --in Room at Bottom Right   --Optimal Action= 2  --Value= 11.111111111563469
# --State in line= 4  column= 9  --in Room at Bottom Right   --Optimal Action= 2  --Value= 12.222222227640405
# --State in line= 5  column= 0  --in Room at Top Left       --Optimal Action= 0  --Value= 5.555555555555555
# --State in line= 5  column= 1  --in Room at Top Left       --Optimal Action= 0  --Value= 4.444444444444445
# --State in line= 5  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= 3.333333333333333
# --State in line= 5  column= 3  --in Room at Top Left       --Optimal Action= 0  --Value= 4.444444444444445
# --State in line= 5  column= 4  --in Room at Top Left       --Optimal Action= 0  --Value= 5.555555555555555
# --State in line= 5  column= 5  --in Room at Top Right      --Optimal Action= 0  --Value= 6.6666666666666705
# --State in line= 5  column= 6  --in Room at Top Right      --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 5  column= 7  --in Room at Top Right      --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 5  column= 8  --in Room at Top Right      --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 5  column= 9  --in Room at Top Right      --Optimal Action= 0  --Value= 11.111111111563469
# --State in line= 6  column= 0  --in Room at Top Left       --Optimal Action= 0  --Value= 4.444444444444445
# --State in line= 6  column= 1  --in Room at Top Left       --Optimal Action= 0  --Value= 3.333333333333333
# --State in line= 6  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= 2.2222222222222223
# --State in line= 6  column= 3  --in Room at Top Left       --Optimal Action= 0  --Value= 3.333333333333333
# --State in line= 6  column= 4  --in Room at Top Left       --Optimal Action= 0  --Value= 4.444444444444445
# --State in line= 6  column= 5  --in Room at Top Right      --Optimal Action= 0  --Value= 5.555555555555555
# --State in line= 6  column= 6  --in Room at Top Right      --Optimal Action= 0  --Value= 6.6666666666666705
# --State in line= 6  column= 7  --in Room at Top Right      --Optimal Action= 0  --Value= 7.777777777777883
# --State in line= 6  column= 8  --in Room at Top Right      --Optimal Action= 0  --Value= 8.8888888888909
# --State in line= 6  column= 9  --in Room at Top Right      --Optimal Action= 0  --Value= 10.000000000032566
# --State in line= 7  column= 0  --in Room at Top Left       --Optimal Action= 0  --Value= 3.333333333333333
# --State in line= 7  column= 1  --in Room at Top Left       --Optimal Action= 0  --Value= 2.2222222222222223
# --State in line= 7  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= 1.1111111111111112
# --State in line= 7  column= 3  --in Room at Top Left       --Optimal Action= 0  --Value= 2.2222222222222223
# --State in line= 7  column= 4  --in Room at Top Left       --Optimal Action= 0  --Value= 3.333333333333333
# --State in line= 7  column= 5  --in Room at Top Right      --Optimal Action= 2  --Value= 4.444444444444445
# --State in line= 7  column= 6  --in Room at Top Right      --Optimal Action= 2  --Value= 5.555555555555555
# --State in line= 7  column= 7  --in Room at Top Right      --Optimal Action= 2  --Value= 6.6666666666666705
# --State in line= 7  column= 8  --in Room at Top Right      --Optimal Action= 2  --Value= 7.777777777777883
# --State in line= 7  column= 9  --in Room at Top Right      --Optimal Action= 2  --Value= 8.8888888888909
# --State in line= 8  column= 0  --in Room at Top Left       --Optimal Action= 0  --Value= 2.2222222222222223
# --State in line= 8  column= 1  --in Room at Top Left       --Optimal Action= 0  --Value= 1.1111111111111112
# --State in line= 8  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 8  column= 3  --in Room at Top Left       --Optimal Action= 0  --Value= 1.1111111111111112
# --State in line= 8  column= 4  --in Room at Top Left       --Optimal Action= 0  --Value= 2.2222222222222223
# --State in line= 8  column= 5  --in Room at Top Right      --Optimal Action= 1  --Value= 5.555555555555555
# --State in line= 8  column= 6  --in Room at Top Right      --Optimal Action= 1  --Value= 6.6666666666666705
# --State in line= 8  column= 7  --in Room at Top Right      --Optimal Action= 1  --Value= 7.777777777777883
# --State in line= 8  column= 8  --in Room at Top Right      --Optimal Action= 1  --Value= 8.8888888888909
# --State in line= 8  column= 9  --in Room at Top Right      --Optimal Action= 1  --Value= 10.000000000032566
# --State in line= 9  column= 0  --in Room at Top Left       --Optimal Action= 3  --Value= 1.1111111111111112
# --State in line= 9  column= 1  --in Room at Top Left       --Optimal Action= 3  --Value= 0.0
# --State in line= 9  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= -1.1111111111111112
# --State in line= 9  column= 3  --in Room at Top Left       --Optimal Action= 2  --Value= 0.0
# --State in line= 9  column= 4  --in Room at Top Left       --Optimal Action= 2  --Value= 1.1111111111111112
# --State in line= 9  column= 5  --in Room at Top Right      --Optimal Action= 1  --Value= 6.6666666666666705
# --State in line= 9  column= 6  --in Room at Top Right      --Optimal Action= 1  --Value= 7.777777777777883
# --State in line= 9  column= 7  --in Room at Top Right      --Optimal Action= 1  --Value= 8.8888888888909
# --State in line= 9  column= 8  --in Room at Top Right      --Optimal Action= 1  --Value= 10.000000000032566
# --State in line= 9  column= 9  --in Room at Top Right      --Optimal Action= 1  --Value= 11.111111111563469
# --State in line= 10  column= 0  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 1  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 2  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 3  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 4  --in Room at Top Left       --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 5  --in Room at Top Right      --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 6  --in Room at Top Right      --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 7  --in Room at Top Right      --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 8  --in Room at Top Right      --Optimal Action= 0  --Value= 0.0
# --State in line= 10  column= 9  --in Room at Top Right      --Optimal Action= 0  --Value= 0.0
